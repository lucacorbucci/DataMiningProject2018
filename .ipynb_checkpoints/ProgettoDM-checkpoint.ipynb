# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from sklearn import preprocessing


df = pd.read_csv("credit_default_train.csv")

# %%
df.head(3)
# Out:
#     limit     sex        education   status  age  ps-sep  ps-aug  ps-jul  \
# 0   50000    male  graduate school      NaN   25       2       0       0
# 1  200000    male       university  married   54      -1      -1      -1
# 2   30000  female      high school  married   -1       2       3       2
#
#    ps-jun  ps-may       ...        ba-jun  ba-may  ba-apr  pa-sep  pa-aug  \
# 0       0       0       ...         49535   30358   30302    2130    1905
# 1      -1      -1       ...          6335    4616    7956   10120    7852
# 2       2       2       ...         30496   29731   29047       0    1700
#
#    pa-jul  pa-jun  pa-may  pa-apr  credit_default
# 0    1811    1100    1100    1200              no
# 1    6336    4622    7956    5499              no
# 2    1100       3    1053    1303              no
#
# [3 rows x 24 columns]

# %%
# Per capire in quali campi ci sono valori null
df.isnull().any()
# Out:
# limit             False
# sex                True
# education          True
# status             True
# age               False
# ps-sep            False
# ps-aug            False
# ps-jul            False
# ps-jun            False
# ps-may            False
# ps-apr            False
# ba-sep            False
# ba-aug            False
# ba-jul            False
# ba-jun            False
# ba-may            False
# ba-apr            False
# pa-sep            False
# pa-aug            False
# pa-jul            False
# pa-jun            False
# pa-may            False
# pa-apr            False
# credit_default    False
# dtype: bool

# %%
# Per sapere quanti valori sono null
df.isnull().sum()
# Out:
# limit                0
# sex                100
# education          127
# status            1822
# age                  0
# ps-sep               0
# ps-aug               0
# ps-jul               0
# ps-jun               0
# ps-may               0
# ps-apr               0
# ba-sep               0
# ba-aug               0
# ba-jul               0
# ba-jun               0
# ba-may               0
# ba-apr               0
# pa-sep               0
# pa-aug               0
# pa-jul               0
# pa-jun               0
# pa-may               0
# pa-apr               0
# credit_default       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 24 columns):
# limit             10000 non-null int64
# sex               9900 non-null object
# education         9873 non-null object
# status            8178 non-null object
# age               10000 non-null int64
# ps-sep            10000 non-null int64
# ps-aug            10000 non-null int64
# ps-jul            10000 non-null int64
# ps-jun            10000 non-null int64
# ps-may            10000 non-null int64
# ps-apr            10000 non-null int64
# ba-sep            10000 non-null int64
# ba-aug            10000 non-null int64
# ba-jul            10000 non-null int64
# ba-jun            10000 non-null int64
# ba-may            10000 non-null int64
# ba-apr            10000 non-null int64
# pa-sep            10000 non-null int64
# pa-aug            10000 non-null int64
# pa-jul            10000 non-null int64
# pa-jun            10000 non-null int64
# ...

# %%
df['sex'].value_counts()
# Out:
# female    6032
# male      3868
# Name: sex, dtype: int64

# %%
df.describe()
# Out:
#                limit           age        ps-sep        ps-aug        ps-jul  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean   167197.000000     32.020200     -0.004000     -0.127800     -0.175700
# std    128975.488596     13.843119      1.132834      1.200921      1.193554
# min     10000.000000     -1.000000     -2.000000     -2.000000     -2.000000
# 25%     50000.000000     26.000000     -1.000000     -1.000000     -1.000000
# 50%    140000.000000     33.000000      0.000000      0.000000      0.000000
# 75%    240000.000000     40.000000      0.000000      0.000000      0.000000
# max    780000.000000     75.000000      8.000000      7.000000      8.000000
#
#              ps-jun        ps-may        ps-apr         ba-sep         ba-aug  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean      -0.234300     -0.263700     -0.297400   51490.704100   49239.438400
# ...

# %%
correlation = df.corr()

# %%
sns.set(style="white")

# Generate a mask for the upper triangle
mask = np.zeros_like(correlation, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
fig = plt.figure(figsize=(12,12))
fig_dims = (3,2)

plt.subplot2grid(fig_dims, (0, 0))
df['education'].value_counts().plot(kind='bar', 
                                   title='Education')
plt.xticks(rotation=0)

plt.subplot2grid(fig_dims, (0,1))
df['sex'].value_counts().plot(kind='bar', 
                                   title='Sex')
plt.xticks(rotation=0)

plt.subplot2grid(fig_dims, (1,0))
df['status'].value_counts().plot(kind='bar', 
                                   title='Status')
plt.xticks(rotation=0)
plt.show()

# %%
df['age'].hist(bins=15)
plt.title("Istogramma eta'")
# Out:
# Text(0.5,1,"Istogramma eta'")

# %%
df['age'].value_counts().hist()

# %%
# Grafico in cui vediamo le persone che hanno o non hanno credit default rispetto all'età.
# In particolare in verde ci sono le persone che hanno avuto un credit default e in rosso quelle che 
# invece non hanno il credit default

plt.scatter(df[df['credit_default'] == 'yes']['age'].unique(), 
            df[df['credit_default'] == 'yes']['age'].value_counts(), color='g', marker='*')

plt.scatter(df[df['credit_default'] == 'no']['age'].unique(), 
            df[df['credit_default'] == 'no']['age'].value_counts(), color='r', marker='+')

plt.show()

# %%
# Pclass
pclass_xt = pd.crosstab(df['age'], df['credit_default'])


fig, axes = plt.subplots(figsize=(15,8))

pclass_xt.plot(kind='bar', stacked=True,ax=axes, 
                   title="Situazione del credit default rispetto all'eta'")
plt.xlabel('Eta')
plt.ylabel('Frequenza credit_default')
plt.xticks(rotation=0)
plt.show()

# %%
fig, axes = plt.subplots(6, 1, figsize=(10,15))
axes[0].hist(df['ps-apr'], bins=20)
axes[0].set_title('Aprile')

axes[1].hist(df['ps-may'], bins=20)
axes[1].set_title('Maggio')

axes[2].hist(df['ps-jun'], bins=20)
axes[2].set_title('Giugno')

axes[3].hist(df['ps-jul'], bins=20)
axes[3].set_title('Luglio')

axes[4].hist(df['ps-aug'], bins=20)
axes[4].set_title('Agosto')

axes[5].hist(df['ps-sep'], bins=20)
axes[5].set_title('Settembre')
# Out:
# Text(0.5,1,'Settembre')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


sns.scatterplot(data = df['ba-apr'])

# %%
fig = plt.figure(figsize=(20,20))
fig_dims = (3,3)

plt.subplot2grid(fig_dims, (0, 0))
b = sns.countplot(df['sex'])
plt.xticks(rotation=0)
b.set_xlabel("Sex",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=25)
plt.xticks(rotation=90)

plt.subplot2grid(fig_dims, (0,1))
b = sns.countplot(df['status'])
plt.xticks(rotation=0)
b.set_xlabel("Status",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=25)
plt.xticks(rotation=90)

plt.subplot2grid(fig_dims, (0,2))
b = sns.countplot(df['education'])
plt.xticks(rotation=0)
b.set_xlabel("Education",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=25)
plt.xticks(rotation=90)

#b = plt.subplot2grid(fig_dims, (1,1))
#df['age'].hist(bins=15)
#b.set_xlabel("Age",fontsize=20)
#b.set_ylabel("Count",fontsize=20)
#b.tick_params(labelsize=25)


plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(20,20))
fig_dims = (3,2)

ax = plt.subplot2grid(fig_dims, (0, 0))
ax.set_yscale('log')
sns.distplot(df['ba-apr'], kde=False)

plt.subplot2grid(fig_dims, (0, 1))
ax.set_yscale('log')
sns.distplot(df['ba-may'], kde=False, ax = ax)

plt.subplot2grid(fig_dims, (1, 0))
ax.set_yscale('log')
sns.distplot(df['ba-jun'], kde=False, ax = ax)

plt.subplot2grid(fig_dims, (1, 1))
ax.set_yscale('log')
sns.distplot(df['ba-jul'], kde=False, ax = ax)

plt.subplot2grid(fig_dims, (2, 0))
ax.set_yscale('log')
sns.distplot(df['ba-aug'], kde=False, ax = ax)

plt.subplot2grid(fig_dims, (2, 1))
ax.set_yscale('log')
sns.distplot(df['ba-sep'], kde=False, ax = ax)

plt.show()
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/ticker.py:2207: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   "Data has no positive values, and therefore cannot be "
# /usr/local/lib/python2.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df.head()
# Out:
#     limit     sex        education   status  age  ps-sep  ps-aug  ps-jul  \
# 0   50000    male  graduate school      NaN   25       2       0       0
# 1  200000    male       university  married   54      -1      -1      -1
# 2   30000  female      high school  married   -1       2       3       2
# 3  140000  female       university   single   -1       0       0       0
# 4   60000  female      high school  married   36       1       2       2
#
#    ps-jun  ps-may       ...        ba-jun  ba-may  ba-apr  pa-sep  pa-aug  \
# 0       0       0       ...         49535   30358   30302    2130    1905
# 1      -1      -1       ...          6335    4616    7956   10120    7852
# 2       2       2       ...         30496   29731   29047       0    1700
# 3       0       0       ...         25224   26855   23783    2000    2000
# 4       0       0       ...         48738   49601   52773    1788       0
#
#    pa-jul  pa-jun  pa-may  pa-apr  credit_default
# ...

# %%
aiutati = df[(df['ps-sep'] == -2) | (df['ps-aug'] == -2) | (df['ps-jul'] == -2) | (df['ps-jun'] == -2) | (df['ps-may'] == -2) | (df['ps-apr'] == -2)]

# %%
fig = plt.figure(figsize=(15,10))
b = aiutati['credit_default'].value_counts().plot(kind='bar', title='Situazione degli utenti che hanno usufruito del credito rotativo')
plt.xticks(rotation=0)
b.set_xlabel("Credit Default",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=20)

# %%
zero = df[(df['ps-sep'] == 0) | (df['ps-aug'] == 0) | (df['ps-jul'] == 0) | (df['ps-jun'] == 0) | (df['ps-may'] == 0) | (df['ps-apr'] == 0)]
fig = plt.figure(figsize=(15,10))
b = zero['credit_default'].value_counts().plot(kind='bar', title='Situazione degli utenti che hanno usufruito del credito rotativo')
plt.xticks(rotation=0)
b.set_xlabel("Credit Default",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=20)

# %%
fig = plt.figure(figsize=(20,20))
fig_dims = (3,3)

ax = plt.subplot2grid(fig_dims, (0, 0))
ax.set_yscale('log')
b = sns.distplot(df['ba-apr'], kde=False)
plt.xticks(rotation=0)
b.set_xlabel("Bill Amount Aprile",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=25)

ax = plt.subplot2grid(fig_dims, (0, 1))
ax.set_yscale('log')
b = sns.distplot(df['ba-may'], kde=False, ax = ax)
plt.xticks(rotation=0)
b.set_xlabel("Bill Amount Maggio",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=25)

ax = plt.subplot2grid(fig_dims, (0, 2))
ax.set_yscale('log')
b = sns.distplot(df['ba-jun'], kde=False, ax = ax)
plt.xticks(rotation=0)
b.set_xlabel("Bill Amount Giugno",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=25)

ax = plt.subplot2grid(fig_dims, (1, 0))
ax.set_yscale('log')
b = sns.distplot(df['ba-jul'], kde=False, ax = ax)
plt.xticks(rotation=0)
b.set_xlabel("Bill Amount Luglio",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=25)

ax = plt.subplot2grid(fig_dims, (1, 1))
ax.set_yscale('log')
b = sns.distplot(df['ba-aug'], kde=False, ax = ax)
plt.xticks(rotation=0)
b.set_xlabel("Bill Amount Agosto",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=25)

ax = plt.subplot2grid(fig_dims, (1, 2))
ax.set_yscale('log')
b = sns.distplot(df['ba-sep'], kde=False, ax = ax)
plt.xticks(rotation=0)
b.set_xlabel("Bill Amount Settembre",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=25)

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(20,20))
fig_dims = (3,3)

ax = plt.subplot2grid(fig_dims, (0, 0))
ax.set_yscale('log')
b = sns.distplot(df['pa-apr'], kde=False)
plt.xticks(rotation=0)
b.set_xlabel("Payment Amount Aprile",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=25)

ax = plt.subplot2grid(fig_dims, (0, 1))
ax.set_yscale('log')
b = sns.distplot(df['pa-may'], kde=False, ax = ax)
plt.xticks(rotation=0)
b.set_xlabel("Payment Amount Maggio",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=25)

ax = plt.subplot2grid(fig_dims, (0, 2))
ax.set_yscale('log')
b = sns.distplot(df['pa-jun'], kde=False, ax = ax)
plt.xticks(rotation=0)
b.set_xlabel("Payment Amount Giugno",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=25)

ax = plt.subplot2grid(fig_dims, (1, 0))
ax.set_yscale('log')
b = sns.distplot(df['pa-jul'], kde=False, ax = ax)
plt.xticks(rotation=0)
b.set_xlabel("Payment Amount Luglio",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=25)

ax = plt.subplot2grid(fig_dims, (1, 1))
ax.set_yscale('log')
b = sns.distplot(df['pa-aug'], kde=False, ax = ax)
plt.xticks(rotation=0)
b.set_xlabel("Payment Amount Agosto",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=25)

ax = plt.subplot2grid(fig_dims, (1, 2))
ax.set_yscale('log')
b = sns.distplot(df['pa-sep'], kde=False, ax = ax)
plt.xticks(rotation=0)
b.set_xlabel("Payment Amount Settembre",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=25)

plt.show()

# %%
fig = plt.figure(figsize=(5,5))
fig_dims = (3,3)

b = plt.subplot2grid(fig_dims, (0,0))
df['age'].hist(bins=15)
b.set_xlabel("Age",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=25)





pclass_xt = pd.crosstab(df['age'], df['credit_default'])


b = plt.subplot2grid(fig_dims, (0,1))

pclass_xt.plot(kind='bar', stacked=True,
                   title="Situazione del credit default rispetto all'eta'")
b.set_xlabel('Eta')
b.set_ylabel('Frequenza credit_default')

plt.show()

# %%
df['MediaPS'] = df.iloc[:,5:11].mean(axis=1)

# %%
df['MediaPS']
# Out:
# 0       0.333333
# 1      -1.000000
# 2       1.833333
# 3       0.000000
# 4       0.833333
# 5      -0.666667
# 6       2.500000
# 7       0.000000
# 8       0.333333
# 9       1.500000
# 10      0.000000
# 11     -0.833333
# 12      0.333333
# 13      0.000000
# 14     -1.166667
# 15      0.000000
# 16     -0.166667
# 17      3.166667
# 18     -0.500000
# 19      0.000000
# 20     -1.166667
# 21      0.000000
# 22      1.500000
# 23     -1.000000
# 24      0.666667
# 25     -1.000000
# 26     -0.833333
# 27      0.000000
# 28     -0.833333
# 29      0.000000
#           ...
# 9970   -0.333333
# 9971    0.000000
# 9972   -1.500000
# 9973   -1.666667
# 9974    0.333333
# 9975   -0.333333
# 9976    2.000000
# 9977    0.000000
# 9978   -2.000000
# 9979   -0.666667
# 9980   -2.000000
# 9981    0.000000
# 9982    0.000000
# 9983   -1.666667
# 9984    0.000000
# 9985   -1.000000
# 9986    0.000000
# 9987   -0.833333
# 9988    0.000000
# 9989    0.000000
# 9990   -0.166667
# ...

# %%
fig = plt.figure(figsize=(12,5))
fig_dims = (3,3)


sns.lineplot(x=df['MediaPS'].unique(), y = df['MediaPS'].value_counts())

# %%
df['MediaBA'] = df.iloc[:,11:18].mean(axis=1)

fig = plt.figure(figsize=(12,5))
fig_dims = (3,3)


ax = sns.lineplot(x=df['MediaBA'].unique(), y = df['MediaBA'].value_counts())
ax.set_yscale('log')

# %%
df['MediaPA'] = df.iloc[:,18:24].mean(axis=1)

fig = plt.figure(figsize=(12,5))
fig_dims = (3,3)


ax = sns.lineplot(x=df['MediaPA'].unique(), y = df['MediaPA'].value_counts())
ax.set_yscale('log')
